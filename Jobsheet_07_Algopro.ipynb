# %% [markdown]
# <a href="https://colab.research.google.com/github/rikiulirniam/AlgoritmaPemrograman/blob/main/Jobsheet_07_Algopro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # -> Praktikum

# %% [markdown]
# ## Praktikum 01 – Tuple: Data Tetap yang Tidak Bisa Diubah

# %%
koordinat = (7.05, 110.44)
print("Lintang:", koordinat[0])
print("Bujur:", koordinat[1])
# Out:
# Lintang: 7.05
# Bujur: 110.44

# %% [markdown]
# ## Praktikum 02 – Dictionary Dasar: Menyimpan Data Mahasiswa

# %%
mahasiswa = {
    "NIM" : "20251001",
    "Nama" : "Andi",
    "Prodi" : "TRK"
}
print("NIM :", mahasiswa["NIM"])
print("Nama:", mahasiswa["Nama"])
print("Prodi:", mahasiswa["Prodi"])
# Out:
# NIM : 20251001
# Nama: Andi
# Prodi: TRK

# %% [markdown]
# ## Praktikum 03 – Operasi pada Dictionary

# %%
mahasiswa = {
    "NIM" : "20251001",
    "Nama" : "Andi",
    "Prodi" : "TRK"
}

mahasiswa["Umur"] = 20
mahasiswa["Prodi"] = "Teknik Komputer"
print(mahasiswa)
del mahasiswa["Umur"]

print(mahasiswa)
# Out:
# {'NIM': '20251001', 'Nama': 'Andi', 'Prodi': 'Teknik Komputer', 'Umur': 20}
# {'NIM': '20251001', 'Nama': 'Andi', 'Prodi': 'Teknik Komputer'}

# %% [markdown]
# ## Praktikum 04 – Set dan Operasi Himpunan

# %%
A = {1, 2, 3, 4}
B = {3, 4, 5, 6}
print("Union:", A | B) # Muncul sekali
print("Intersection:", A & B) # Data yang sama
print("Difference:", A - B) # Apa yang ada di A tapi tidak ada di B
# Out:
# Union: {1, 2, 3, 4, 5, 6}
# Intersection: {3, 4}
# Difference: {1, 2}

# %% [markdown]
# ## Praktikum 05 – Studi Kasus: Data Mahasiswa dan Mata Kuliah

# %%
mhs1 = {"Algoritma", "Matematika", "Bahasa Inggris"}
mhs2 = {"Algoritma", "Basis Data", "Matematika"}
print("Mata kuliah Mhs1:", mhs1)
print("Mata kuliah Mhs2:", mhs2)
print("Mata kuliah yang sama:", mhs1 & mhs2)
# Out:
# Mata kuliah Mhs1: {'Algoritma', 'Bahasa Inggris', 'Matematika'}
# Mata kuliah Mhs2: {'Basis Data', 'Algoritma', 'Matematika'}
# Mata kuliah yang sama: {'Algoritma', 'Matematika'}

# %% [markdown]
# ## Praktikum 06 – Studi Kasus Dictionary: Daftar Nilai Mahasiswa

# %%
nilai_mahasiswa = {
    "Andi": 80,
    "Budi": 75,
    "Cici": 90
}

for nama, nilai in nilai_mahasiswa.items():
    print(f"{nama}: {nilai}")

rata = sum(nilai_mahasiswa.values()) / len(nilai_mahasiswa)
print(f"Rata-rata nilai: {rata:.2f}")
# Out:
# Andi: 80
# Budi: 75
# Cici: 90
# Rata-rata nilai: 81.67

# %% [markdown]
# # -> Penugasan

# %% [markdown]
# ## Tuple Sederhana

# %%
mhs = ("43325022", 18, "TRK")
print("NIM:", mhs[0])
print("Umur:", mhs[1])
print("Prodi:", mhs[2])
# Out:
# NIM: 43325022
# Umur: 18
# Prodi: TRK

# %% [markdown]
# ## Tuple Tidak Bisa Diubah

# %%
num = (1, 2, 3)
num[0] = 99
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-157956205.py in <cell line: 0>()
#       1 num = (1, 2, 3)
# ----> 2 num[0] = 99
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ## Dictionary Dasar

# %%
book = {"Judul": "Algoritma", "Penulis": "Munir", "Tahun": 2021}
print("Judul:", book["Judul"])
print("Penulis:", book["Penulis"])
print("Tahun:", book["Tahun"])
# Out:
# Judul: Algoritma
# Penulis: Munir
# Tahun: 2021

# %% [markdown]
# ## Operasi Dictionary

# %%
dosen = {"NIP": "12345", "Nama": "Budi", "Prodi": "TRK"}

dosen["Umur"] = 40
dosen["Prodi"] = "Teknik Komputer"
del dosen["Umur"]
print(dosen)
# Out:
# {'NIP': '12345', 'Nama': 'Budi', 'Prodi': 'Teknik Komputer'}

# %% [markdown]
# ## Set dan Himpunan

# %%
A = {"Matematika", "Algoritma", "Bahasa Inggris"}
B = {"Algoritma", "Basis Data", "Matematika"}

print("Union:", A | B)
print("Intersection:", A & B)
print("Difference:", A - B)
# Out:
# Union: {'Basis Data', 'Algoritma', 'Bahasa Inggris', 'Matematika'}
# Intersection: {'Algoritma', 'Matematika'}
# Difference: {'Bahasa Inggris'}

# %% [markdown]
# ## Studi Kasus Dictionary

# %%
nilai_mahasiswa = {"Andi": 85, "Budi": 90, "Cici": 78}

for nama, nilai in nilai_mahasiswa.items():
    print(f"{nama} : {nilai}")
rata = sum(nilai_mahasiswa.values()) / len(nilai_mahasiswa)
print(f"Rata-rata nilai: {rata:.2f}")
# Out:
# Andi : 85
# Budi : 90
# Cici : 78
# Rata-rata nilai: 84.33

# %% [markdown]
# ## Studi Kasus Set – Klub Mahasiswa

# %%
klub_a = {"Andi", "Budi", "Cici"}
klub_b = {"Cici", "Deni", "Eka"}

print(f"Daftar seluruh anggota : {klub_a | klub_b}")
print(f"Anggota yang ada di kedua klub : {klub_a & klub_b}")
print(f"Anggota yang ada di klub A tetapi tidak di Klub B : {klub_a - klub_b}")
# Out:
# Daftar seluruh anggota : {'Deni', 'Eka', 'Andi', 'Budi', 'Cici'}
# Anggota yang ada di kedua klub : {'Cici'}
# Anggota yang ada di klub A tetapi tidak di Klub B : {'Andi', 'Budi'}
